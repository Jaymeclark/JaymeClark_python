# %% [markdown]
# # Pandas: Working with Data Frames - summarizing with groupby

# %%
import numpy as np              #standard imports
import scipy as sc
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ## Read the Hall of Fame dataset from the Baseball-Databank

# %%
hall = pd.read_csv("../../../../baseballdatabank/core/HallOfFame.csv")

# %% [markdown]
# ## List the first 5 rows of the hall Data Frame

# %%
hall.head()
# Out:
#     playerID  yearid votedBy  ballots  needed  votes inducted category  \
# 0   cobbty01    1936   BBWAA    226.0   170.0  222.0        Y   Player
# 1   ruthba01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 2  wagneho01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 3  mathech01    1936   BBWAA    226.0   170.0  205.0        Y   Player
# 4  johnswa01    1936   BBWAA    226.0   170.0  189.0        Y   Player
#
#   needed_note
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ## Show the column names of the hall Data Frame

# %%
hall.columns
# Out:
# Index(['playerID', 'yearid', 'votedBy', 'ballots', 'needed', 'votes',
#        'inducted', 'category', 'needed_note'],
#       dtype='object')

# %% [markdown]
# ## List the number of records for each category

# %%
hall.groupby('category').count()
# Out:
#                    playerID  yearid  votedBy  ballots  needed  votes  \
# category
# Manager                  74      74       74       51      51     51
# Pioneer/Executive        39      39       39        7       7      7
# Player                 3997    3997     3997     3869    3712   3869
# Umpire                   10      10       10        0       0      0
#
#                    inducted  needed_note
# category
# Manager                  74            0
# Pioneer/Executive        39            0
# Player                 3997          157
# Umpire                   10            0

# %% [markdown]
# ## List the votedBy counts

# %%
hall.groupby('votedBy').count()
# Out:
#                   playerID  yearid  ballots  needed  votes  inducted  \
# votedBy
# BBWAA                 3689    3689     3689    3689   3689      3689
# Centennial               6       6        0       0      0         6
# Final Ballot            21      21       21      21     21        21
# Negro League            26      26        0       0      0        26
# Nominating Vote         76      76       76       0     76        76
# Old Timers              30      30        0       0      0        30
# Run Off                 81      81       81       0     81        81
# Special Election         2       2        0       0      0         2
# Veterans               189     189       60      60     60       189
#
#                   category  needed_note
# votedBy
# BBWAA                 3689            0
# Centennial               6            0
# Final Ballot            21            0
# Negro League            26            0
# Nominating Vote         76           76
# Old Timers              30            0
# Run Off                 81           81
# Special Election         2            0
# Veterans               189            0

# %% [markdown]
# ## Two-level groupby

# %%
hall.groupby(('category','votedBy')).count()
# Out:
#                                     playerID  yearid  ballots  needed  votes  \
# category          votedBy
# Manager           BBWAA                   51      51       51      51     51
#                   Centennial               1       1        0       0      0
#                   Old Timers               1       1        0       0      0
#                   Veterans                21      21        0       0      0
# Pioneer/Executive BBWAA                    7       7        7       7      7
#                   Centennial               5       5        0       0      0
#                   Negro League             5       5        0       0      0
#                   Old Timers               4       4        0       0      0
#                   Veterans                18      18        0       0      0
# Player            BBWAA                 3631    3631     3631    3631   3631
#                   Final Ballot            21      21       21      21     21
#                   Negro League            21      21        0       0      0
#                   Nominating Vote         76      76       76       0     76
#                   Old Timers              25      25        0       0      0
#                   Run Off                 81      81       81       0     81
#                   Special Election         2       2        0       0      0
#                   Veterans               140     140       60      60     60
# Umpire            Veterans                10      10        0       0      0
#
#                                     inducted  needed_note
# category          votedBy
# Manager           BBWAA                   51            0
#                   Centennial               1            0
#                   Old Timers               1            0
#                   Veterans                21            0
# Pioneer/Executive BBWAA                    7            0
#                   Centennial               5            0
#                   Negro League             5            0
#                   Old Timers               4            0
#                   Veterans                18            0
# Player            BBWAA                 3631            0
#                   Final Ballot            21            0
#                   Negro League            21            0
#                   Nominating Vote         76           76
#                   Old Timers              25            0
#                   Run Off                 81           81
#                   Special Election         2            0
#                   Veterans               140            0
# Umpire            Veterans                10            0

# %%
hall.groupby(('votedBy','category')).count()
# Out:
#                                     playerID  yearid  ballots  needed  votes  \
# votedBy          category
# BBWAA            Manager                  51      51       51      51     51
#                  Pioneer/Executive         7       7        7       7      7
#                  Player                 3631    3631     3631    3631   3631
# Centennial       Manager                   1       1        0       0      0
#                  Pioneer/Executive         5       5        0       0      0
# Final Ballot     Player                   21      21       21      21     21
# Negro League     Pioneer/Executive         5       5        0       0      0
#                  Player                   21      21        0       0      0
# Nominating Vote  Player                   76      76       76       0     76
# Old Timers       Manager                   1       1        0       0      0
#                  Pioneer/Executive         4       4        0       0      0
#                  Player                   25      25        0       0      0
# Run Off          Player                   81      81       81       0     81
# Special Election Player                    2       2        0       0      0
# Veterans         Manager                  21      21        0       0      0
#                  Pioneer/Executive        18      18        0       0      0
#                  Player                  140     140       60      60     60
#                  Umpire                   10      10        0       0      0
#
#                                     inducted  needed_note
# votedBy          category
# BBWAA            Manager                  51            0
#                  Pioneer/Executive         7            0
#                  Player                 3631            0
# Centennial       Manager                   1            0
#                  Pioneer/Executive         5            0
# Final Ballot     Player                   21            0
# Negro League     Pioneer/Executive         5            0
#                  Player                   21            0
# Nominating Vote  Player                   76           76
# Old Timers       Manager                   1            0
#                  Pioneer/Executive         4            0
#                  Player                   25            0
# Run Off          Player                   81           81
# Special Election Player                    2            0
# Veterans         Manager                  21            0
#                  Pioneer/Executive        18            0
#                  Player                  140            0
#                  Umpire                   10            0

# %% [markdown]
# ## Groupby with selection - groupby over a subset

# %%
hall[hall.votedBy=='Veterans'].groupby('category').count()
# Out:
#                    playerID  yearid  votedBy  ballots  needed  votes  \
# category
# Manager                  21      21       21        0       0      0
# Pioneer/Executive        18      18       18        0       0      0
# Player                  140     140      140       60      60     60
# Umpire                   10      10       10        0       0      0
#
#                    inducted  needed_note
# category
# Manager                  21            0
# Pioneer/Executive        18            0
# Player                  140            0
# Umpire                   10            0

# %% [markdown]
# Note that there is no indication that the above list is only 'Veterans'.  We can use a two-level groupby in this case:

# %%
hall[hall.votedBy=='Veterans'].groupby(('votedBy','category')).count()
# Out:
#                             playerID  yearid  ballots  needed  votes  \
# votedBy  category
# Veterans Manager                  21      21        0       0      0
#          Pioneer/Executive        18      18        0       0      0
#          Player                  140     140       60      60     60
#          Umpire                   10      10        0       0      0
#
#                             inducted  needed_note
# votedBy  category
# Veterans Manager                  21            0
#          Pioneer/Executive        18            0
#          Player                  140            0
#          Umpire                   10            0

# %% [markdown]
# ## Read the master Data Frame and list the column names

# %%
master = pd.read_csv("../../../../baseballdatabank/core/Master.csv")
master.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %% [markdown]
# ## Exercise: produce a list showing the counts of hall of fame inductees by year

# %%
#
hall.groupby(('yearid','inducted')).count()
# Out:
#                  playerID  votedBy  ballots  needed  votes  category  \
# yearid inducted
# 1936   N              105      105      105     105    105       105
#        Y                5        5        5       5      5         5
# 1937   N              110      110      110     110    110       110
#        Y                8        8        3       3      3         8
# 1938   N              119      119      119     119    119       119
#        Y                3        3        1       1      1         3
# 1939   N              105      105      105     105    105       105
#        Y               10       10        3       3      3        10
# 1942   N               71       71       71      71     71        71
#        Y                1        1        1       1      1         1
# 1944   Y                1        1        0       0      0         1
# 1945   N               95       95       95      95     95        95
#        Y               10       10        0       0      0        10
# 1946   N               97       97       97      21     97        97
#        Y               11       11        0       0      0        11
# 1947   N               35       35       35      35     35        35
#        Y                4        4        4       4      4         4
# 1948   N              104      104      104     104    104       104
#        Y                2        2        2       2      2         2
# 1949   N              117      117      117      98    117       117
#        Y                3        3        1       0      1         3
# 1950   N              100      100      100     100    100       100
# 1951   N               84       84       84      84     84        84
#        Y                2        2        2       2      2         2
# 1952   N               73       73       73      73     73        73
#        Y                2        2        2       2      2         2
# 1953   N               81       81       81      81     81        81
#        Y                8        8        2       2      2         8
# 1954   N               50       50       50      50     50        50
#        Y                3        3        3       3      3         3
# ...                   ...      ...      ...     ...    ...       ...
# 2002   N               27       27       27      27     27        27
#        Y                1        1        1       1      1         1
# 2003   N               31       31       31      31     31        31
#        Y                2        2        2       2      2         2
# 2004   N               30       30       30      30     30        30
#        Y                2        2        2       2      2         2
# 2005   N               25       25       25      25     25        25
#        Y                2        2        2       2      2         2
# 2006   N               28       28       28      28     28        28
#        Y               18       18        1       1      1        18
# 2007   N               30       30       30      30     30        30
#        Y                2        2        2       2      2         2
# 2008   N               24       24       24      24     24        24
#        Y                6        6        1       1      1         6
# 2009   N               21       21       21      21     21        21
#        Y                3        3        2       2      2         3
# 2010   N               25       25       25      25     25        25
#        Y                3        3        1       1      1         3
# 2011   N               31       31       31      31     31        31
#        Y                3        3        2       2      2         3
# 2012   N               26       26       26      26     26        26
#        Y                2        2        1       1      1         2
# 2013   N               37       37       37      37     37        37
#        Y                3        3        0       0      0         3
# 2014   N               33       33       33      33     33        33
#        Y                6        6        3       3      3         6
# 2015   N               30       30       30      30     30        30
#        Y                4        4        4       4      4         4
# 2016   N               30       30       30      30     30        30
#        Y                2        2        2       2      2         2
#
#                  needed_note
# yearid inducted
# 1936   N                   0
#        Y                   0
# 1937   N                   0
#        Y                   0
# 1938   N                   0
#        Y                   0
# 1939   N                   0
#        Y                   0
# 1942   N                   0
#        Y                   0
# 1944   Y                   0
# 1945   N                   0
#        Y                   0
# 1946   N                  76
#        Y                   0
# 1947   N                   0
#        Y                   0
# 1948   N                   0
#        Y                   0
# 1949   N                  19
#        Y                   1
# 1950   N                   0
# 1951   N                   0
#        Y                   0
# 1952   N                   0
#        Y                   0
# 1953   N                   0
#        Y                   0
# 1954   N                   0
#        Y                   0
# ...                      ...
# 2002   N                   0
#        Y                   0
# 2003   N                   0
#        Y                   0
# 2004   N                   0
#        Y                   0
# 2005   N                   0
#        Y                   0
# 2006   N                   0
#        Y                   0
# 2007   N                   0
#        Y                   0
# 2008   N                   0
#        Y                   0
# 2009   N                   0
#        Y                   0
# 2010   N                   0
#        Y                   0
# 2011   N                   0
#        Y                   0
# 2012   N                   0
#        Y                   0
# 2013   N                   0
#        Y                   0
# 2014   N                   0
#        Y                   0
# 2015   N                   0
#        Y                   0
# 2016   N                   0
#        Y                   0
#
# [147 rows x 7 columns]

# %%
hall[hall.inducted=='Y'].groupby('yearid').count()
# Out:
#         playerID  votedBy  ballots  needed  votes  inducted  category  \
# yearid
# 1936           5        5        5       5      5         5         5
# 1937           8        8        3       3      3         8         8
# 1938           3        3        1       1      1         3         3
# 1939          10       10        3       3      3        10        10
# 1942           1        1        1       1      1         1         1
# 1944           1        1        0       0      0         1         1
# 1945          10       10        0       0      0        10        10
# 1946          11       11        0       0      0        11        11
# 1947           4        4        4       4      4         4         4
# 1948           2        2        2       2      2         2         2
# 1949           3        3        1       0      1         3         3
# 1951           2        2        2       2      2         2         2
# 1952           2        2        2       2      2         2         2
# 1953           8        8        2       2      2         8         8
# 1954           3        3        3       3      3         3         3
# 1955           6        6        4       4      4         6         6
# 1956           2        2        2       2      2         2         2
# 1957           2        2        0       0      0         2         2
# 1959           1        1        0       0      0         1         1
# 1961           2        2        0       0      0         2         2
# 1962           4        4        2       2      2         4         4
# 1963           4        4        0       0      0         4         4
# 1964           7        7        1       0      1         7         7
# 1965           1        1        0       0      0         1         1
# 1966           2        2        1       1      1         2         2
# 1967           3        3        1       0      1         3         3
# 1968           3        3        1       1      1         3         3
# 1969           4        4        2       2      2         4         4
# 1970           4        4        1       1      1         4         4
# 1971           8        8        0       0      0         8         8
# ...          ...      ...      ...     ...    ...       ...       ...
# 1987           3        3        2       2      2         3         3
# 1988           1        1        1       1      1         1         1
# 1989           4        4        2       2      2         4         4
# 1990           2        2        2       2      2         2         2
# 1991           5        5        3       3      3         5         5
# 1992           4        4        2       2      2         4         4
# 1993           1        1        1       1      1         1         1
# 1994           3        3        1       1      1         3         3
# 1995           5        5        1       1      1         5         5
# 1996           4        4        0       0      0         4         4
# 1997           4        4        1       1      1         4         4
# 1998           5        5        1       1      1         5         5
# 1999           7        7        3       3      3         7         7
# 2000           5        5        2       2      2         5         5
# 2001           4        4        2       2      2         4         4
# 2002           1        1        1       1      1         1         1
# 2003           2        2        2       2      2         2         2
# 2004           2        2        2       2      2         2         2
# 2005           2        2        2       2      2         2         2
# 2006          18       18        1       1      1        18        18
# 2007           2        2        2       2      2         2         2
# 2008           6        6        1       1      1         6         6
# 2009           3        3        2       2      2         3         3
# 2010           3        3        1       1      1         3         3
# 2011           3        3        2       2      2         3         3
# 2012           2        2        1       1      1         2         2
# 2013           3        3        0       0      0         3         3
# 2014           6        6        3       3      3         6         6
# 2015           4        4        4       4      4         4         4
# 2016           2        2        2       2      2         2         2
#
#         needed_note
# yearid
# 1936              0
# 1937              0
# 1938              0
# 1939              0
# 1942              0
# 1944              0
# 1945              0
# 1946              0
# 1947              0
# 1948              0
# 1949              1
# 1951              0
# 1952              0
# 1953              0
# 1954              0
# 1955              0
# 1956              0
# 1957              0
# 1959              0
# 1961              0
# 1962              0
# 1963              0
# 1964              1
# 1965              0
# 1966              0
# 1967              1
# 1968              0
# 1969              0
# 1970              0
# 1971              0
# ...             ...
# 1987              0
# 1988              0
# 1989              0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
#
# [75 rows x 8 columns]

# %%
hall[['playerID','inducted','yearid']][hall.inducted=='Y'].groupby('yearid').count()
# Out:
#         playerID  inducted
# yearid
# 1936           5         5
# 1937           8         8
# 1938           3         3
# 1939          10        10
# 1942           1         1
# 1944           1         1
# 1945          10        10
# 1946          11        11
# 1947           4         4
# 1948           2         2
# 1949           3         3
# 1951           2         2
# 1952           2         2
# 1953           8         8
# 1954           3         3
# 1955           6         6
# 1956           2         2
# 1957           2         2
# 1959           1         1
# 1961           2         2
# 1962           4         4
# 1963           4         4
# 1964           7         7
# 1965           1         1
# 1966           2         2
# 1967           3         3
# 1968           3         3
# 1969           4         4
# 1970           4         4
# 1971           8         8
# ...          ...       ...
# 1987           3         3
# 1988           1         1
# 1989           4         4
# 1990           2         2
# 1991           5         5
# 1992           4         4
# 1993           1         1
# 1994           3         3
# 1995           5         5
# 1996           4         4
# 1997           4         4
# 1998           5         5
# 1999           7         7
# 2000           5         5
# 2001           4         4
# 2002           1         1
# 2003           2         2
# 2004           2         2
# 2005           2         2
# 2006          18        18
# 2007           2         2
# 2008           6         6
# 2009           3         3
# 2010           3         3
# 2011           3         3
# 2012           2         2
# 2013           3         3
# 2014           6         6
# 2015           4         4
# 2016           2         2
#
# [75 rows x 2 columns]

# %% [markdown]
# ## Exercise: produce a list showing the counts of living hall of fame inductees by year

# %%
#

masterhall= pd.merge(hall[hall.inducted=='Y'], master[master.deathYear.isnull()], how='inner')
masterhall[['playerID', 'deathYear']]
# Out:
#      playerID  deathYear
# 0   koufasa01        NaN
# 1    fordwh01        NaN
# 2    mayswi01        NaN
# 3   kalinal01        NaN
# 4   gibsobo01        NaN
# 5   aaronha01        NaN
# 6   robinfr02        NaN
# 7   robinbr01        NaN
# 8   maricju01        NaN
# 9   aparilu01        NaN
# 10  brocklo01        NaN
# 11  mccovwi01        NaN
# 12  doerrbo01        NaN
# 13  willibi01        NaN
# 14  benchjo01        NaN
# 15  yastrca01        NaN
# 16  schoere01        NaN
# 17  palmeji01        NaN
# 18  morgajo02        NaN
# 19  carewro01        NaN
# 20  perryga01        NaN
# 21  jenkife01        NaN
# 22  seaveto01        NaN
# 23  fingero01        NaN
# 24  jacksre01        NaN
# 25  carltst01        NaN
# 26  schmimi01        NaN
# 27  bunniji01        NaN
# 28  niekrph01        NaN
# 29  lasorto01        NaN
# ..        ...        ...
# 39  smithoz01        NaN
# 40  murraed02        NaN
# 41  molitpa01        NaN
# 42  eckerde01        NaN
# 43  boggswa01        NaN
# 44  sandbry01        NaN
# 45  suttebr01        NaN
# 46  ripkeca01        NaN
# 47  gossari01        NaN
# 48  henderi01        NaN
# 49   riceji01        NaN
# 50  dawsoan01        NaN
# 51  herzowh01        NaN
# 52  harvedo99        NaN
# 53  alomaro01        NaN
# 54  blylebe01        NaN
# 55  gillipa99        NaN
# 56  larkiba01        NaN
# 57    coxbo01        NaN
# 58  larusto01        NaN
# 59  torrejo01        NaN
# 60  maddugr01        NaN
# 61  glavito02        NaN
# 62  thomafr04        NaN
# 63  johnsra05        NaN
# 64  martipe02        NaN
# 65  smoltjo01        NaN
# 66  biggicr01        NaN
# 67  griffke02        NaN
# 68  piazzmi01        NaN
#
# [69 rows x 2 columns]

# %% [markdown]
# ## Exercise: produce a list showing the number of times each player was voted on for induction into the hall of fame

# %%
hall.groupby(('playerID', 'votes')).sum()
# Out:
#                  yearid  ballots  needed
# playerID  votes
# aaronha01 406.0    1982    415.0   312.0
# abbotji01 13.0     2005    516.0   387.0
# adamsba01 4.0      1948    121.0    91.0
#           5.0      1949    153.0   115.0
#           6.0      3896    370.0   126.0
#           7.0      1945    247.0   186.0
#           8.0      1937    201.0   151.0
#           9.0      1952    234.0   176.0
#           11.0     5819    769.0   578.0
#           12.0     1951    226.0   170.0
#           13.0     1954    252.0   189.0
#           17.0     1953    264.0   198.0
#           22.0     1947    161.0   121.0
#           24.0     1955    251.0   189.0
# adamsbo03 1.0      1966    302.0   227.0
# adamssp01 1.0      3918    535.0   402.0
# ageeto01  0.0      1979    432.0   324.0
# aguilri01 3.0      2006    520.0   390.0
# akerja01  0.0      1980    385.0   289.0
# alexado01 0.0      1995    460.0   345.0
# alexape01 55.0     1936    226.0   170.0
#           125.0    1937    201.0   151.0
#           212.0    1938    262.0   197.0
# allenbe01 0.0      1979    432.0   324.0
# allendi01 14.0     1983    374.0   281.0
#           28.0     1985    395.0   297.0
#           35.0     1989    447.0   336.0
#           41.0     1986    425.0   319.0
#           52.0     1988    427.0   321.0
#           55.0     1987    413.0   310.0
# ...                 ...      ...     ...
# yeagest01 2.0      1992    430.0   323.0
# yerkest02 1.0      1945    247.0   186.0
# yorkru01  1.0      1962    160.0   120.0
#           10.0     1964    201.0   151.0
# youngcy01 32.0     1936     78.0    59.0
#           111.0    1936    226.0   170.0
#           153.0    1937    201.0   151.0
# younger01 1.0      2012    573.0   430.0
# youngpe01 1.0      1958    266.0   200.0
# youngro01 10.0     1936    226.0   170.0
#           11.0     1949    187.0     NaN
#           16.0     1937    201.0   151.0
#           17.0     1950    168.0   126.0
#           19.0     3904    314.0   236.0
#           20.0     1949    153.0   115.0
#           22.0     1945    247.0   186.0
#           25.0     1946    202.0     NaN
#           31.0     1953    264.0   198.0
#           34.0     7796    986.0   741.0
#           36.0     1947    161.0   121.0
#           40.0     1938    262.0   197.0
#           44.0     1942    233.0   175.0
#           48.0     1955    251.0   189.0
# yountro01 385.0    1999    497.0   373.0
# zachato01 1.0      3918    535.0   402.0
# zachrpa01 0.0      1991    443.0   333.0
# zahnge01  0.0      1991    443.0   333.0
# zeileto01 0.0      2010    539.0   405.0
# zimmech01 1.0      1938    262.0   197.0
# ziskri01  0.0      1989    447.0   336.0
#
# [3344 rows x 3 columns]
